# %% [markdown]
# # Breast Cancer Survival
#
# ### This is for the project of Term1 and 2. The data of Breast Cancer Survival is read from the csv that is locally saved

# %%
import numpy as np
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sb
from datetime import datetime

# %matplotlib inline

# %% [markdown]
# #### Instantiating the variables required for this program

# %%
# Input csv where there data exists
input_csv = "/Users/pradeep.sampath/Desktop/pradeep/Sampy/Work/Learning/INSAID/Term1_2/Data/Term-1-master/Data/Projects/Breast_cancer_survival.csv"

# Profiling File name of input data
input_profiling_filename = "BreastCancerSurvivalProfiling.html"

# Profiling title of input data
profiling_title = "Pandas Profiling of Breast Cancer Survival"

# %%
# Breast Cancer Survival DataFrame
bcs_df = pd.read_csv(input_csv)

bcs_pr = bcs_df.profile_report(title=profiling_title, style={'full_width':True})

bcs_pr.to_file(output_file=input_profiling_filename)

# %% [markdown]
# #### Following are the Questions in mind:
#
# 1. What ages did it affect most?
# 2. As age increases, does people had more chances of getting affected or less?
# 3. What are the chances of early recovery as the age increases?
# 4. As the years go by, will the chances of people getting affected was more or less?
# 5. Does age create a factor of having less axillary nodes or more
# 6. Does having more number of axillary nodes mean early recovery or slow?
# 7. Will lower age people get affected with more axillary nodes or less
# 8. Whether major people have less axillary nodes or more
# 9. How many people got operated-on for Breast Cancer over the years?

# %%
bcs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
# Age                   306 non-null int64
# Years_of_operation    306 non-null int64
# Pos_axillary_nodes    306 non-null int64
# Status                306 non-null int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
bcs_df.describe(include="all")
# Out:
#               Age  Years_of_operation  Pos_axillary_nodes      Status
# count  306.000000          306.000000          306.000000  306.000000
# mean    52.457516           62.852941            4.026144    1.264706
# std     10.803452            3.249405            7.189654    0.441899
# min     30.000000           58.000000            0.000000    1.000000
# 25%     44.000000           60.000000            0.000000    1.000000
# 50%     52.000000           63.000000            1.000000    1.000000
# 75%     60.750000           65.750000            4.000000    2.000000
# max     83.000000           69.000000           52.000000    2.000000

# %% [markdown]
# ### Visualizing the data

# %%
bcs_df.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11dbd2c88>,
# ...
#       dtype=object)

# %%
sb.set()
sb.pairplot(bcs_df, size=2.5);

# %%
sb.violinplot("Years_of_operation", "Age", data=bcs_df, palette=["lightblue", "lightpink"]);

# %%
bcs_df.boxplot()

# %% [markdown]
# ## Understanding data for the questions that are formatted
#
# ### How many people got operated-on for Breast Cancer over the years?

# %%
bcs_df['Years_of_operation'].value_counts().sort_index().plot(kind='bar')

# %% [markdown]
# #### As per the data above, the people getting operated on Breast Cancer gradually decreased over the years. The reason may be that either less people were affected or less people required being operated

# %% [markdown]
# .
# #### Age Visualization:

# %%
bcs_df['Age'].value_counts().sort_index().plot(kind='bar')

# %% [markdown]
# ### What ages did it affect most?
#
# ### As age increases, does people had more chances of getting affected or less?
#
# #### People of ages in 40s and 50s got mostly operated for Breast Cancer, with 50s the most

# %% [markdown]
# .
#
# ### What are the chances of early recovery as the age increases?

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the Age against the Status
ax.scatter(bcs_df['Age'], bcs_df['Status'])

# set a title and labels
ax.set_xlabel('Age')
ax.set_ylabel('Status')
# Out:
# Text(0, 0.5, 'Status')

# %% [markdown]
# #### Majorily the people who got operated survived more than 5 years, even though there are quite a good number of them who survived for less than 5 years post operation

# %% [markdown]
# ## 'Age' vs 'Axillary Nodes' Visualization

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the Age against the Number of Axillary Nodes
ax.scatter(bcs_df['Age'], bcs_df['Pos_axillary_nodes'])

# set a title and labels
ax.set_xlabel('Age')
ax.set_ylabel('Number of positive axillary nodes detected')
# Out:
# Text(0, 0.5, 'Number of positive axillary nodes detected')

# %% [markdown]
# ### Does age create a factor of having less axillary nodes or more?
# ### Will lower age people get affected with more axillary nodes or less?
#
#
#
# #### Over the ages, majorily the number of Axillary Nodes are zero, followed by one Node
#
#
# ### Whether major people have less axillary nodes or more?
#
# #### Major people have less Axillary Nodes

# %% [markdown]
# .
#
# # 'Axillary Nodes' vs 'Survival Status' Visualization

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the Number of Axillary Nodes against the Status
ax.scatter(bcs_df['Pos_axillary_nodes'], bcs_df['Status'])

# set a title and labels
ax.set_xlabel('Number of positive axillary nodes detected')
ax.set_ylabel('Survival Status')
# Out:
# Text(0, 0.5, 'Survival Status')

# %% [markdown]
# ### Does having more number of axillary nodes mean early recovery or slow?
# #### The chances of survival for more than 5 years is less as the number of Axillary Nodes increases
